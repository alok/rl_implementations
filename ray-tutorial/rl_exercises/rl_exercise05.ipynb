# %% [markdown]
# # RL Exercise 5 - Evolution Strategies
#
# **GOAL:** The goal of this exercise is to demonstrate how to use the evolution strategies (ES) algorithm.
#
# ES is described in detail in https://arxiv.org/abs/1703.03864.
#
# The ES algorithm works as follows.
#
# - It maintains a distribution over policies (which in this case is a multivariate Gaussian distribution over the weights of a neural network policy represented by the mean of the Gaussian $\theta$).
# - The mean of the distribution is updated at each iteration, from $\theta_0$ to $\theta_1$ to $\theta_2$ and so on.
# - At each iteration, a large number of policies are sampled from the distribution over policies and rollouts are performed using these **perturbed policies**.
# - The distribution over policies is updated by moving its mean in the direction of the perturbed policies that achieved higher reward.
#
# Of the algorithms explored so far, this one is the closest to the Monte Carlo algorithm implemented in one of the earlier exercises.
#
# **NOTE:** One interesting property of this algorithm is that it only cares about the rewards achieved in a given rollout. The algorithm does not need to know the states that were visited and so much less data has to be communicated.

# %%
import gym
import ray
from ray.rllib.es import ESAgent, DEFAULT_CONFIG
# Out:
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# Start up Ray. This must be done before we instantiate any RL agents. We pass in num_workers=0 because the training agent's constructor will create a number of actors.

# %%
ray.init(num_workers=0)
# Out:
# Waiting for redis server at 127.0.0.1:42482 to respond...
# Waiting for redis server at 127.0.0.1:52355 to respond...
# Starting local scheduler with the following resources: {'CPU': 8, 'GPU': 0}.
#
# ======================================================================
# View the web UI at http://localhost:8898/notebooks/ray_ui44606.ipynb?token=b7d8c131ad525d221aa469187a41cac7b6a262e4f55c8abc
# ======================================================================
# {'local_scheduler_socket_names': ['/tmp/scheduler3128764'],
#  'node_ip_address': '127.0.0.1',
#  'object_store_addresses': [ObjectStoreAddress(name='/tmp/plasma_store62765532', manager_name='/tmp/plasma_manager19938805', manager_port=46649)],
#  'redis_address': '127.0.0.1:42482',
#  'webui_url': 'http://localhost:8898/notebooks/ray_ui44606.ipynb?token=b7d8c131ad525d221aa469187a41cac7b6a262e4f55c8abc'}

# %% [markdown]
# Instantiate an ESAgent object. We pass in a config object that specifies how the network and training procedure should be configured. Some of the parameters are the following.
#
# - `num_workers` is the number of actors that the agent will create. This determines the degree of parallelism that will be used.
# - `episodes_per_batch` is the minimum number of rollouts to perform at each iteration.
# - `timesteps_per_batch` is the minimum number of steps of the environment to perform at each iteration.
# - `noise_stdev` is the standard deviation of the multivariate Gaussian distribution over the neural net policy weights.
# - `stepsize` is the size of the update to the distribution over policies to take at each iteration.

# %%
config = DEFAULT_CONFIG.copy()
config['num_workers'] = 3
config['episodes_per_batch'] = 100
config['timesteps_per_batch'] = 1000
config['noise_stdev'] = 0.02
config['stepsize'] = 0.01

agent = ESAgent(config, 'MountainCar-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation shape is (2,)
# Not using any observation preprocessor.
# Constructing fcnet [256, 256] <function tanh at 0x11dc82378>
# Creating shared noise table.
# Creating actors.

# %% [markdown]
# **EXERCISE:** Train the agent for some number of steps on the CartPole environment. Compare the performance to PPO from the previous exercise.

# %%
for _ in range(50):
    result = agent.train()
# Out:
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 514      |
# | GradNorm            | 4.37     |
# | UpdateRatio         | 0.115    |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 108      |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 2.16e+04 |
# | TimeElapsedThisIter | 13.4     |
# | TimeElapsed         | 13.5     |
# ----------------------------------
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:262: RuntimeWarning: Mean of empty slice.
#   tlogger.record_tabular("EvalEpRewMean", eval_returns.mean())
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:105: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:264: RuntimeWarning: Mean of empty slice.
#   tlogger.record_tabular("EvalEpLenMean", eval_lengths.mean())
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:296: RuntimeWarning: Mean of empty slice.
#   episode_reward_mean=eval_returns.mean(),
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:297: RuntimeWarning: Mean of empty slice.
#   episode_len_mean=eval_lengths.mean(),
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/tune/logger.py:168: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(value, float):
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/tune/logger.py:170: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(value, int):
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 518      |
# | GradNorm            | 4.38     |
# | UpdateRatio         | 0.0809   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 216      |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 4.32e+04 |
# | TimeElapsedThisIter | 2.93     |
# | TimeElapsed         | 16.5     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 82 episodes 16400 timesteps so far this iter
# Collected 94 episodes 18800 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | -200     |
# | EvalEpRewStd        | 0        |
# | EvalEpLenMean       | 200      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 522      |
# | GradNorm            | 5.18     |
# | UpdateRatio         | 0.0661   |
# | EpisodesThisIter    | 106      |
# | EpisodesSoFar       | 322      |
# | TimestepsThisIter   | 2.12e+04 |
# | TimestepsSoFar      | 6.44e+04 |
# | TimeElapsedThisIter | 2.91     |
# | TimeElapsed         | 19.4     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 6 episodes 1200 timesteps so far this iter
# Collected 18 episodes 3600 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 527      |
# | GradNorm            | 5.12     |
# | UpdateRatio         | 0.0574   |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 424      |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 8.48e+04 |
# | TimeElapsedThisIter | 2.84     |
# | TimeElapsed         | 22.3     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 532      |
# | GradNorm            | 4.36     |
# | UpdateRatio         | 0.0511   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 532      |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.06e+05 |
# | TimeElapsedThisIter | 3.03     |
# | TimeElapsed         | 25.3     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 536      |
# | GradNorm            | 4.37     |
# | UpdateRatio         | 0.0464   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 640      |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.28e+05 |
# | TimeElapsedThisIter | 3.07     |
# | TimeElapsed         | 28.4     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 6 episodes 1200 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 74 episodes 14800 timesteps so far this iter
# Collected 86 episodes 17200 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | -200     |
# | EvalEpRewStd        | 0        |
# | EvalEpLenMean       | 200      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 541      |
# | GradNorm            | 4.42     |
# | UpdateRatio         | 0.043    |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 748      |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.5e+05  |
# | TimeElapsedThisIter | 3.6      |
# | TimeElapsed         | 32       |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 545      |
# | GradNorm            | 5.1      |
# | UpdateRatio         | 0.0404   |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 850      |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 1.7e+05  |
# | TimeElapsedThisIter | 3.3      |
# | TimeElapsed         | 35.3     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 549      |
# | GradNorm            | 4.39     |
# | UpdateRatio         | 0.0381   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 958      |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.92e+05 |
# | TimeElapsedThisIter | 3.08     |
# | TimeElapsed         | 38.4     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 553      |
# | GradNorm            | 4.44     |
# | UpdateRatio         | 0.0362   |
# | EpisodesThisIter    | 104      |
# | EpisodesSoFar       | 1.06e+03 |
# | TimestepsThisIter   | 2.08e+04 |
# | TimestepsSoFar      | 2.12e+05 |
# | TimeElapsedThisIter | 3.46     |
# | TimeElapsed         | 41.9     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 6 episodes 1200 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 94 episodes 18800 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 557      |
# | GradNorm            | 5.13     |
# | UpdateRatio         | 0.0349   |
# | EpisodesThisIter    | 106      |
# | EpisodesSoFar       | 1.17e+03 |
# | TimestepsThisIter   | 2.12e+04 |
# | TimestepsSoFar      | 2.34e+05 |
# | TimeElapsedThisIter | 3.87     |
# | TimeElapsed         | 45.8     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 6 episodes 1200 timesteps so far this iter
# Collected 18 episodes 3600 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 64 episodes 12800 timesteps so far this iter
# Collected 76 episodes 15200 timesteps so far this iter
# Collected 88 episodes 17600 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 560      |
# | GradNorm            | 5.13     |
# | UpdateRatio         | 0.0337   |
# | EpisodesThisIter    | 100      |
# | EpisodesSoFar       | 1.27e+03 |
# | TimestepsThisIter   | 2e+04    |
# | TimestepsSoFar      | 2.54e+05 |
# | TimeElapsedThisIter | 3.51     |
# | TimeElapsed         | 49.3     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 6 episodes 1200 timesteps so far this iter
# Collected 14 episodes 2800 timesteps so far this iter
# Collected 20 episodes 4000 timesteps so far this iter
# Collected 26 episodes 5200 timesteps so far this iter
# Collected 32 episodes 6400 timesteps so far this iter
# Collected 44 episodes 8800 timesteps so far this iter
# Collected 56 episodes 11200 timesteps so far this iter
# Collected 62 episodes 12400 timesteps so far this iter
# Collected 68 episodes 13600 timesteps so far this iter
# Collected 80 episodes 16000 timesteps so far this iter
# Collected 86 episodes 17200 timesteps so far this iter
# Collected 98 episodes 19600 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 564      |
# | GradNorm            | 4.39     |
# | UpdateRatio         | 0.0324   |
# | EpisodesThisIter    | 110      |
# | EpisodesSoFar       | 1.38e+03 |
# | TimestepsThisIter   | 2.2e+04  |
# | TimestepsSoFar      | 2.76e+05 |
# | TimeElapsedThisIter | 3.85     |
# | TimeElapsed         | 53.2     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 567      |
# | GradNorm            | 5.15     |
# | UpdateRatio         | 0.0317   |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 1.48e+03 |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 2.96e+05 |
# | TimeElapsedThisIter | 3.43     |
# | TimeElapsed         | 56.6     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 18 episodes 3600 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 74 episodes 14800 timesteps so far this iter
# Collected 80 episodes 16000 timesteps so far this iter
# Collected 86 episodes 17200 timesteps so far this iter
# Collected 92 episodes 18400 timesteps so far this iter
# Collected 98 episodes 19600 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 570      |
# | GradNorm            | 4.46     |
# | UpdateRatio         | 0.0306   |
# | EpisodesThisIter    | 110      |
# | EpisodesSoFar       | 1.59e+03 |
# | TimestepsThisIter   | 2.2e+04  |
# | TimestepsSoFar      | 3.18e+05 |
# | TimeElapsedThisIter | 3.81     |
# | TimeElapsed         | 60.4     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 18 episodes 3600 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 573      |
# | GradNorm            | 5.07     |
# | UpdateRatio         | 0.0299   |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 1.69e+03 |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 3.38e+05 |
# | TimeElapsedThisIter | 3.42     |
# | TimeElapsed         | 63.9     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 575      |
# | GradNorm            | 4.38     |
# | UpdateRatio         | 0.0291   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 1.8e+03  |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 3.6e+05  |
# | TimeElapsedThisIter | 3.11     |
# | TimeElapsed         | 67       |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 577      |
# | GradNorm            | 4.38     |
# | UpdateRatio         | 0.0283   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 1.91e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 3.82e+05 |
# | TimeElapsedThisIter | 3.07     |
# | TimeElapsed         | 70.1     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 580      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0277   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.02e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 4.03e+05 |
# | TimeElapsedThisIter | 2.91     |
# | TimeElapsed         | 73       |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 582      |
# | GradNorm            | 4.35     |
# | UpdateRatio         | 0.0273   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.12e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 4.25e+05 |
# | TimeElapsedThisIter | 3.08     |
# | TimeElapsed         | 76.1     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 583      |
# | GradNorm            | 4.43     |
# | UpdateRatio         | 0.0269   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.23e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 4.46e+05 |
# | TimeElapsedThisIter | 3.01     |
# | TimeElapsed         | 79.1     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 94 episodes 18800 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | -200     |
# | EvalEpRewStd        | 0        |
# | EvalEpLenMean       | 200      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 585      |
# | GradNorm            | 5.14     |
# | UpdateRatio         | 0.0268   |
# | EpisodesThisIter    | 106      |
# | EpisodesSoFar       | 2.34e+03 |
# | TimestepsThisIter   | 2.12e+04 |
# | TimestepsSoFar      | 4.68e+05 |
# | TimeElapsedThisIter | 2.88     |
# | TimeElapsed         | 82       |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 10 episodes 2000 timesteps so far this iter
# Collected 22 episodes 4400 timesteps so far this iter
# Collected 34 episodes 6800 timesteps so far this iter
# Collected 46 episodes 9200 timesteps so far this iter
# Collected 58 episodes 11600 timesteps so far this iter
# Collected 70 episodes 14000 timesteps so far this iter
# Collected 82 episodes 16400 timesteps so far this iter
# Collected 94 episodes 18800 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | -200     |
# | EvalEpRewStd        | 0        |
# | EvalEpLenMean       | 200      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 586      |
# | GradNorm            | 5.11     |
# | UpdateRatio         | 0.0266   |
# | EpisodesThisIter    | 106      |
# | EpisodesSoFar       | 2.44e+03 |
# | TimestepsThisIter   | 2.12e+04 |
# | TimestepsSoFar      | 4.89e+05 |
# | TimeElapsedThisIter | 2.85     |
# | TimeElapsed         | 84.9     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 588      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0263   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.55e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 5.1e+05  |
# | TimeElapsedThisIter | 2.97     |
# | TimeElapsed         | 87.9     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 589      |
# | GradNorm            | 4.39     |
# | UpdateRatio         | 0.0259   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.66e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 5.32e+05 |
# | TimeElapsedThisIter | 2.89     |
# | TimeElapsed         | 90.8     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 590      |
# | GradNorm            | 4.4      |
# | UpdateRatio         | 0.0256   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.77e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 5.54e+05 |
# | TimeElapsedThisIter | 2.88     |
# | TimeElapsed         | 93.7     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 591      |
# | GradNorm            | 4.43     |
# | UpdateRatio         | 0.0254   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 2.88e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 5.75e+05 |
# | TimeElapsedThisIter | 2.86     |
# | TimeElapsed         | 96.5     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 592      |
# | GradNorm            | 5.08     |
# | UpdateRatio         | 0.0255   |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 2.98e+03 |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 5.96e+05 |
# | TimeElapsedThisIter | 2.93     |
# | TimeElapsed         | 99.5     |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 593      |
# | GradNorm            | 4.39     |
# | UpdateRatio         | 0.0253   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 3.09e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 6.17e+05 |
# | TimeElapsedThisIter | 2.91     |
# | TimeElapsed         | 102      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 594      |
# | GradNorm            | 4.36     |
# | UpdateRatio         | 0.0252   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 3.19e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 6.39e+05 |
# | TimeElapsedThisIter | 3.26     |
# | TimeElapsed         | 106      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 594      |
# | GradNorm            | 4.39     |
# | UpdateRatio         | 0.025    |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 3.3e+03  |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 6.6e+05  |
# | TimeElapsedThisIter | 3.17     |
# | TimeElapsed         | 109      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 68 episodes 13600 timesteps so far this iter
# Collected 80 episodes 16000 timesteps so far this iter
# Collected 86 episodes 17200 timesteps so far this iter
# Collected 92 episodes 18400 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 595      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0249   |
# | EpisodesThisIter    | 104      |
# | EpisodesSoFar       | 3.41e+03 |
# | TimestepsThisIter   | 2.08e+04 |
# | TimestepsSoFar      | 6.81e+05 |
# | TimeElapsedThisIter | 3.16     |
# | TimeElapsed         | 112      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 595      |
# | GradNorm            | 5.12     |
# | UpdateRatio         | 0.025    |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 3.51e+03 |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 7.02e+05 |
# | TimeElapsedThisIter | 2.82     |
# | TimeElapsed         | 115      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 596      |
# | GradNorm            | 4.35     |
# | UpdateRatio         | 0.0248   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 3.62e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 7.23e+05 |
# | TimeElapsedThisIter | 2.95     |
# | TimeElapsed         | 118      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 54 episodes 10800 timesteps so far this iter
# Collected 66 episodes 13200 timesteps so far this iter
# Collected 78 episodes 15600 timesteps so far this iter
# Collected 90 episodes 18000 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 596      |
# | GradNorm            | 5.13     |
# | UpdateRatio         | 0.025    |
# | EpisodesThisIter    | 102      |
# | EpisodesSoFar       | 3.72e+03 |
# | TimestepsThisIter   | 2.04e+04 |
# | TimestepsSoFar      | 7.44e+05 |
# | TimeElapsedThisIter | 3.11     |
# | TimeElapsed         | 121      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 5.17     |
# | UpdateRatio         | 0.0251   |
# | EpisodesThisIter    | 106      |
# | EpisodesSoFar       | 3.82e+03 |
# | TimestepsThisIter   | 2.12e+04 |
# | TimestepsSoFar      | 7.65e+05 |
# | TimeElapsedThisIter | 3        |
# | TimeElapsed         | 124      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 30 episodes 6000 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.4      |
# | UpdateRatio         | 0.0249   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 3.93e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 7.86e+05 |
# | TimeElapsedThisIter | 3.17     |
# | TimeElapsed         | 127      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 42 episodes 8400 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.39     |
# | UpdateRatio         | 0.0247   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.04e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 8.08e+05 |
# | TimeElapsedThisIter | 3.19     |
# | TimeElapsed         | 130      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.37     |
# | UpdateRatio         | 0.0245   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.15e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 8.3e+05  |
# | TimeElapsedThisIter | 2.91     |
# | TimeElapsed         | 133      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0244   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.26e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 8.51e+05 |
# | TimeElapsedThisIter | 2.87     |
# | TimeElapsed         | 136      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.4      |
# | UpdateRatio         | 0.0243   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.36e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 8.73e+05 |
# | TimeElapsedThisIter | 2.89     |
# | TimeElapsed         | 139      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.43     |
# | UpdateRatio         | 0.0242   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.47e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 8.94e+05 |
# | TimeElapsedThisIter | 3        |
# | TimeElapsed         | 142      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0242   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.58e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 9.16e+05 |
# | TimeElapsedThisIter | 2.87     |
# | TimeElapsed         | 145      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.34     |
# | UpdateRatio         | 0.0241   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.69e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 9.38e+05 |
# | TimeElapsedThisIter | 2.89     |
# | TimeElapsed         | 148      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.38     |
# | UpdateRatio         | 0.0241   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.8e+03  |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 9.59e+05 |
# | TimeElapsedThisIter | 2.87     |
# | TimeElapsed         | 151      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.43     |
# | UpdateRatio         | 0.024    |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 4.9e+03  |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 9.81e+05 |
# | TimeElapsedThisIter | 2.91     |
# | TimeElapsed         | 154      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 598      |
# | GradNorm            | 4.37     |
# | UpdateRatio         | 0.0239   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 5.01e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1e+06    |
# | TimeElapsedThisIter | 2.84     |
# | TimeElapsed         | 157      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.36     |
# | UpdateRatio         | 0.0239   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 5.12e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.02e+06 |
# | TimeElapsedThisIter | 2.88     |
# | TimeElapsed         | 159      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0239   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 5.23e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.05e+06 |
# | TimeElapsedThisIter | 3.02     |
# | TimeElapsed         | 162      |
# ----------------------------------
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.38     |
# | UpdateRatio         | 0.0239   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 5.34e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.07e+06 |
# | TimeElapsedThisIter | 2.86     |
# | TimeElapsed         | 165      |
# ----------------------------------

# %%
result
# Out:
# TrainingResult(timesteps_total=1067200, done=None, info={'weights_norm': 596.88995, 'grad_norm': 4.378503, 'update_ratio': 0.023926882, 'episodes_this_iter': 108, 'episodes_so_far': 5336, 'timesteps_this_iter': 21600, 'timesteps_so_far': 1067200, 'time_elapsed_this_iter': 2.8604001998901367, 'time_elapsed': 165.33793687820435}, episode_reward_mean=nan, episode_len_mean=nan, episodes_total=None, mean_accuracy=None, mean_validation_accuracy=None, mean_loss=None, neg_mean_loss=None, experiment_id='773acd52fa664b419eaf9e37d350e226', training_iteration=50, timesteps_this_iter=21600, time_this_iter_s=2.865279197692871, time_total_s=164.7182047367096, pid=21775, date='2018-03-28_22-33-29', timestamp=1522301609, hostname='DILBAG-M-X2Y6', config={'l2_coeff': 0.005, 'noise_stdev': 0.02, 'episodes_per_batch': 100, 'timesteps_per_batch': 1000, 'eval_prob': 0.003, 'return_proc_mode': 'centered_rank', 'num_workers': 3, 'stepsize': 0.01, 'observation_filter': 'MeanStdFilter', 'noise_size': 250000000, 'env_config': {}, 'env': 'MountainCar-v0'})

# %% [markdown]
# **EXERCISE:** Instantiate an `ESAgent` object on the `MountainCar-v0` environment and train it for some number of steps. Compare the performance to PPO and A3C from the previous exercise.

# %%
agent.train()
# Out:
# Collected 0 episodes 0 timesteps so far this iter
# Collected 12 episodes 2400 timesteps so far this iter
# Collected 24 episodes 4800 timesteps so far this iter
# Collected 36 episodes 7200 timesteps so far this iter
# Collected 48 episodes 9600 timesteps so far this iter
# Collected 60 episodes 12000 timesteps so far this iter
# Collected 72 episodes 14400 timesteps so far this iter
# Collected 84 episodes 16800 timesteps so far this iter
# Collected 96 episodes 19200 timesteps so far this iter
# ----------------------------------
# | EvalEpRewMean       | nan      |
# | EvalEpRewStd        | nan      |
# | EvalEpLenMean       | nan      |
# | EpRewMean           | -200     |
# | EpRewStd            | 0        |
# | EpLenMean           | 200      |
# | Norm                | 597      |
# | GradNorm            | 4.41     |
# | UpdateRatio         | 0.0239   |
# | EpisodesThisIter    | 108      |
# | EpisodesSoFar       | 5.44e+03 |
# | TimestepsThisIter   | 2.16e+04 |
# | TimestepsSoFar      | 1.09e+06 |
# | TimeElapsedThisIter | 3.24     |
# | TimeElapsed         | 4.66e+03 |
# ----------------------------------
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:262: RuntimeWarning: Mean of empty slice.
#   tlogger.record_tabular("EvalEpRewMean", eval_returns.mean())
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:105: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:264: RuntimeWarning: Mean of empty slice.
#   tlogger.record_tabular("EvalEpLenMean", eval_lengths.mean())
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:296: RuntimeWarning: Mean of empty slice.
#   episode_reward_mean=eval_returns.mean(),
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/rllib/es/es.py:297: RuntimeWarning: Mean of empty slice.
#   episode_len_mean=eval_lengths.mean(),
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/tune/logger.py:168: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(value, float):
# /Users/alokbeniwal/Library/Python/3.6/lib/python/site-packages/ray/tune/logger.py:170: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(value, int):
# TrainingResult(timesteps_total=1088800, done=None, info={'weights_norm': 596.59485, 'grad_norm': 4.41005, 'update_ratio': 0.02394891, 'episodes_this_iter': 108, 'episodes_so_far': 5444, 'timesteps_this_iter': 21600, 'timesteps_so_far': 1088800, 'time_elapsed_this_iter': 3.2404000759124756, 'time_elapsed': 4655.842152833939}, episode_reward_mean=nan, episode_len_mean=nan, episodes_total=None, mean_accuracy=None, mean_validation_accuracy=None, mean_loss=None, neg_mean_loss=None, experiment_id='773acd52fa664b419eaf9e37d350e226', training_iteration=51, timesteps_this_iter=21600, time_this_iter_s=3.248440980911255, time_total_s=167.96664571762085, pid=21775, date='2018-03-28_23-48-20', timestamp=1522306100, hostname='DILBAG-M-X2Y6', config={'l2_coeff': 0.005, 'noise_stdev': 0.02, 'episodes_per_batch': 100, 'timesteps_per_batch': 1000, 'eval_prob': 0.003, 'return_proc_mode': 'centered_rank', 'num_workers': 3, 'stepsize': 0.01, 'observation_filter': 'MeanStdFilter', 'noise_size': 250000000, 'env_config': {}, 'env': 'MountainCar-v0'})
